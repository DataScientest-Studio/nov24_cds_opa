# %%
pip install alpha_vantage
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.fundamentaldata import FundamentalData
import pandas as pd

# Alpha vantage limité à 25 essais, commentée pour éviter une erreur

api_key_fpm = "?apikey=XC1Cy8GyQ1LceyauN1mHbce84WIVcL7V"

# %%
import requests

# Récupération des tickers NASDAQ sur wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
tables = pd.read_html(url)
sp500 = tables[0]  
tickers = sp500['Symbol'].tolist()
tickers
# DataFrame vide
df_fpm = pd.DataFrame()

# Je requête à l'API pour chaque ticker du NASDAQ
for ticker in tickers:
    response = requests.get(f'https://financialmodelingprep.com/api/v3/key-metrics/{ticker}?period=annual&apikey={api_key_fpm}')
    data = response.json()
    # On merge ici chaque requête dans le df vide
    df_fpm = pd.concat([df_fpm, pd.DataFrame(data)], axis = 0)

df_fpm.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 17
#      15     data = response.json()
#      16     # On merge ici chaque requête dans le df vide
# ---> 17     df_fpm = pd.concat([df_fpm, pd.DataFrame(data)], axis = 0)
#      19 df_fpm.head()
#
# File ~/Library/Python/3.12/lib/python/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
display(sp500)
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
import requests

# Récupération des tickers NASDAQ sur wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
tables = pd.read_html(url)
sp500 = tables[0]  
tickers = sp500['Symbol'].tolist()
tickers
# DataFrame vide
df_fpm = pd.DataFrame()

# Je requête à l'API pour chaque ticker du NASDAQ
for ticker in tickers:
    response = requests.get(f'https://financialmodelingprep.com/api/v3/key-metrics/{ticker}?period=annual&apikey={api_key_fpm}')
    if isinstance(data, list):  # Si c'est une liste, on la traite directement
        df_fpm = pd.concat([df_fpm, pd.DataFrame(data)], axis=0)
    elif isinstance(data, dict):  # Si c'est un dictionnaire, on l'entoure d'une liste
        df_fpm = pd.concat([df_fpm, pd.DataFrame([data])], axis=0)
    else:
        print(f"Format inattendu pour {ticker}: {data}")

df_fpm.head()
# Out:
#                                        Error Message
# 0  Invalid API KEY. Feel free to create a Free AP...
# 0  Invalid API KEY. Feel free to create a Free AP...
# 0  Invalid API KEY. Feel free to create a Free AP...
# 0  Invalid API KEY. Feel free to create a Free AP...
# 0  Invalid API KEY. Feel free to create a Free AP...
